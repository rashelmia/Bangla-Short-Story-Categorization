# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
os.chdir("F:\DIU\Lstm")

# %%
df4 = pd.read_csv("Data.csv")

# %%
df4
# Out:
#                                                    Title  \
# 0               ।। ছদ্মবেশী মৃত্যুদূত ।। । চতুর্থ পর্ব ।
# 1                                                 আলমারি
# 2                              তেজস্ক্রিয় রক্তধ্বনি "১৩"
# 3                                               ভাইব্রেট
# 4                       😍😍সিনিয়র_গুন্ডি_বউ😍 😍লাস্ট পার্ট
# ...                                                  ...
# 30713  তোমাকে বুঝিনা প্রিয় ???? বোঝোনা তুমি আমায় ????...
# 30714                ।। সাজা ।। মেয়ে খেলনা (অন্তিম পর্ব)
# 30715                                     #না_বলা_কথা#৩৩
# 30716                              Devil_Queen - part:12
# 30717             #ভালোবাসার_অন্যরুপ 🌸❤ #সিজন_২ #পর্ব_১২
#
#                          Author  \
# 0                    দেবজিৎ ঘোষ
# 1                      সোমা দাস
# 2            রিয়া খান "অভ্রনীল"
# 3               রায়া চ্যাটার্জী
# 4                      Mou "মৌ"
# ...                         ...
# 30713            CHANDANA BAROI
# ...

# %%
# Look at classification type counts
counts = df4.Category.value_counts()
print(len(counts))
print(counts)
# Out:
# 19
# প্রেমকাহিনী           7594
# রহস্যগল্প             5507
# ধারাবাহিক কাহিনী      2574
# স্মৃতিকথা             2207
# হাস্যকৌতুক            2141
# নারী বিষয়ক কাহিনী     1999
# ছোটগল্প               1986
# ভৌতিক গল্প            1813
# ভ্রমণকাহিনী            918
# শিশু সাহিত্য           856
# অণুগল্প                765
# কাব্য                  761
# প্রবন্ধ                547
# অলীক কাহিনী            491
# স্ব-বিকাশ              290
# সামাজিক গল্প           112
# কল্পবিজ্ঞান কাহিনী      57
# উপন্যাস                 50
# অনুবাদ সাহিত্য          50
# Name: Category, dtype: int64

# %%
# append all coumlns value into a dataframe
cat_5 = df4[df4['Category'].isin(['প্রেমকাহিনী','রহস্যগল্প','ধারাবাহিক কাহিনী','স্মৃতিকথা','হাস্যকৌতুক','নারী বিষয়ক কাহিনী','ছোটগল্প','ভৌতিক গল্প'])]
cat_5.shape
# Out:
# (25821, 4)

# %%
#append natinal1,all_bangladesh1,sports1 with other categorys

final_data =cat_5
final_data.shape
# Out:
# (25821, 4)

# %%
final_data
# Out:
#                                                    Title  \
# 0               ।। ছদ্মবেশী মৃত্যুদূত ।। । চতুর্থ পর্ব ।
# 1                                                 আলমারি
# 2                              তেজস্ক্রিয় রক্তধ্বনি "১৩"
# 4                       😍😍সিনিয়র_গুন্ডি_বউ😍 😍লাস্ট পার্ট
# 5                                        ফিলিংস ফর ইউ-23
# ...                                                  ...
# 30713  তোমাকে বুঝিনা প্রিয় ???? বোঝোনা তুমি আমায় ????...
# 30714                ।। সাজা ।। মেয়ে খেলনা (অন্তিম পর্ব)
# 30715                                     #না_বলা_কথা#৩৩
# 30716                              Devil_Queen - part:12
# 30717             #ভালোবাসার_অন্যরুপ 🌸❤ #সিজন_২ #পর্ব_১২
#
#                          Author  \
# 0                    দেবজিৎ ঘোষ
# 1                      সোমা দাস
# 2            রিয়া খান "অভ্রনীল"
# 4                      Mou "মৌ"
# 5       Mysterious Girl💞 "মিশু"
# ...                         ...
# 30713            CHANDANA BAROI
# ...

# %%
# Look at classification type counts
counts = final_data.Category.value_counts()
print(len(counts))
print(counts)
# Out:
# 8
# প্রেমকাহিনী          7594
# রহস্যগল্প            5507
# ধারাবাহিক কাহিনী     2574
# স্মৃতিকথা            2207
# হাস্যকৌতুক           2141
# নারী বিষয়ক কাহিনী    1999
# ছোটগল্প              1986
# ভৌতিক গল্প           1813
# Name: Category, dtype: int64

# %%
# Check NA counts
final_data.isnull().sum()
# Out:
# Title        0
# Author       5
# Text        75
# Category     0
# dtype: int64

# %%
final_data = final_data.dropna()

# %%
# Check NA counts
final_data.isnull().sum()
# Out:
# Title       0
# Author      0
# Text        0
# Category    0
# dtype: int64

# %%
# Look at classification type counts
counts = final_data.Category.value_counts()
print(len(counts))
print(counts)
# Out:
# 8
# প্রেমকাহিনী          7594
# রহস্যগল্প            5437
# ধারাবাহিক কাহিনী     2574
# স্মৃতিকথা            2207
# হাস্যকৌতুক           2141
# নারী বিষয়ক কাহিনী    1999
# ছোটগল্প              1976
# ভৌতিক গল্প           1813
# Name: Category, dtype: int64

# %%
#max_length=final_data["Text"].str.len().max()
#print(max_length)
#min_length=final_data["Text"].str.len().min()
#print(min_length)

# %%
df56 = final_data
df56.shape
# Out:
# (25741, 4)

# %%
# minimamum length 600 of the body text and maximum 5000
#df56.drop(df56[df56['Text'].str.len() < 600].index, inplace = True)
#df56.shape

# %%
# Look at classification type counts
counts = df56.Category.value_counts()
print(len(counts))
print(counts)
# Out:
# 8
# প্রেমকাহিনী          7594
# রহস্যগল্প            5437
# ধারাবাহিক কাহিনী     2574
# স্মৃতিকথা            2207
# হাস্যকৌতুক           2141
# নারী বিষয়ক কাহিনী    1999
# ছোটগল্প              1976
# ভৌতিক গল্প           1813
# Name: Category, dtype: int64

# %%
#max_length=df56["Text"].str.len().max()
#print(max_length)
#min_length=df56["Text"].str.len().min()
#print(min_length)

# %%
df56
# Out:
#                                                    Title  \
# 0               ।। ছদ্মবেশী মৃত্যুদূত ।। । চতুর্থ পর্ব ।
# 1                                                 আলমারি
# 2                              তেজস্ক্রিয় রক্তধ্বনি "১৩"
# 4                       😍😍সিনিয়র_গুন্ডি_বউ😍 😍লাস্ট পার্ট
# 5                                        ফিলিংস ফর ইউ-23
# ...                                                  ...
# 30713  তোমাকে বুঝিনা প্রিয় ???? বোঝোনা তুমি আমায় ????...
# 30714                ।। সাজা ।। মেয়ে খেলনা (অন্তিম পর্ব)
# 30715                                     #না_বলা_কথা#৩৩
# 30716                              Devil_Queen - part:12
# 30717             #ভালোবাসার_অন্যরুপ 🌸❤ #সিজন_২ #পর্ব_১২
#
#                          Author  \
# 0                    দেবজিৎ ঘোষ
# 1                      সোমা দাস
# 2            রিয়া খান "অভ্রনীল"
# 4                      Mou "মৌ"
# 5       Mysterious Girl💞 "মিশু"
# ...                         ...
# 30713            CHANDANA BAROI
# ...

# %%
df = df56
df
# Out:
#                                                    Title  \
# 0               ।। ছদ্মবেশী মৃত্যুদূত ।। । চতুর্থ পর্ব ।
# 1                                                 আলমারি
# 2                              তেজস্ক্রিয় রক্তধ্বনি "১৩"
# 4                       😍😍সিনিয়র_গুন্ডি_বউ😍 😍লাস্ট পার্ট
# 5                                        ফিলিংস ফর ইউ-23
# ...                                                  ...
# 30713  তোমাকে বুঝিনা প্রিয় ???? বোঝোনা তুমি আমায় ????...
# 30714                ।। সাজা ।। মেয়ে খেলনা (অন্তিম পর্ব)
# 30715                                     #না_বলা_কথা#৩৩
# 30716                              Devil_Queen - part:12
# 30717             #ভালোবাসার_অন্যরুপ 🌸❤ #সিজন_২ #পর্ব_১২
#
#                          Author  \
# 0                    দেবজিৎ ঘোষ
# 1                      সোমা দাস
# 2            রিয়া খান "অভ্রনীল"
# 4                      Mou "মৌ"
# 5       Mysterious Girl💞 "মিশু"
# ...                         ...
# 30713            CHANDANA BAROI
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                                    Title  \
# 0               ।। ছদ্মবেশী মৃত্যুদূত ।। । চতুর্থ পর্ব ।
# 1                                                 আলমারি
# 2                              তেজস্ক্রিয় রক্তধ্বনি "১৩"
# 3                       😍😍সিনিয়র_গুন্ডি_বউ😍 😍লাস্ট পার্ট
# 4                                        ফিলিংস ফর ইউ-23
# ...                                                  ...
# 25736  তোমাকে বুঝিনা প্রিয় ???? বোঝোনা তুমি আমায় ????...
# 25737                ।। সাজা ।। মেয়ে খেলনা (অন্তিম পর্ব)
# 25738                                     #না_বলা_কথা#৩৩
# 25739                              Devil_Queen - part:12
# 25740             #ভালোবাসার_অন্যরুপ 🌸❤ #সিজন_২ #পর্ব_১২
#
#                          Author  \
# 0                    দেবজিৎ ঘোষ
# 1                      সোমা দাস
# 2            রিয়া খান "অভ্রনীল"
# 3                      Mou "মৌ"
# 4       Mysterious Girl💞 "মিশু"
# ...                         ...
# 25736            CHANDANA BAROI
# ...

# %%
import re 
y = []

# %%
for x in df['Text']:
    
    x = "".join(i for i in x if i in ["।"] or 2432 <= ord(i) <= 2559 or ord(i)== 32)
    x = " ".join(x.split())
    y.append(x)

# %%
df['Clean_Text'] = y
# Out:
# <ipython-input-75-65e0226b8364>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Clean_Text'] = y

# %%
df
# Out:
#                                                    Title  \
# 0               ।। ছদ্মবেশী মৃত্যুদূত ।। । চতুর্থ পর্ব ।
# 1                                                 আলমারি
# 2                              তেজস্ক্রিয় রক্তধ্বনি "১৩"
# 3                       😍😍সিনিয়র_গুন্ডি_বউ😍 😍লাস্ট পার্ট
# 4                                        ফিলিংস ফর ইউ-23
# ...                                                  ...
# 25736  তোমাকে বুঝিনা প্রিয় ???? বোঝোনা তুমি আমায় ????...
# 25737                ।। সাজা ।। মেয়ে খেলনা (অন্তিম পর্ব)
# 25738                                     #না_বলা_কথা#৩৩
# 25739                              Devil_Queen - part:12
# 25740             #ভালোবাসার_অন্যরুপ 🌸❤ #সিজন_২ #পর্ব_১২
#
#                          Author  \
# 0                    দেবজিৎ ঘোষ
# 1                      সোমা দাস
# 2            রিয়া খান "অভ্রনীল"
# 3                      Mou "মৌ"
# 4       Mysterious Girl💞 "মিশু"
# ...                         ...
# 25736            CHANDANA BAROI
# ...

# %%
# Check NA counts
df.isnull().sum()
# Out:
# Title         0
# Author        0
# Text          0
# Category      0
# Clean_Text    0
# dtype: int64

# %%
df.Clean_Text[3]
# Out:
# 'গল্প সিনিয়রগুন্ডিবউ লেখক বাংলা আসলে তানিয়া আমায় ভালোবাসে । ও এমন মূহুর্তে আমার সাথে ছিল যখন আমি নিজেই নিজেকে জানতাম না । আমি ওর কাছে ঋণী । কি বলবো ওকে আমি ও বা এখন কি করবে আমার সাথে নাহ ও আমার জন্য অনেক কিছু করেছে । ও যদি আমায় বিয়ে করতে চায় তবে আমার ওকে মেনে নিতেই হবে । তানিয়ার ব্যাপারে চাঁদনিকে জানানো উচিৎ । এসব ভাবতে ভাবতেই নিচে চলে গেলাম । সবাই একসাথে বসে আছে । আরাধা আমাকে দেখেই বাবাই বলে ছুটে আসলো আমার কাছে । আমি ওকে কোলে নিয়ে সবার কাছে গেলাম । চাঁদনিকে দেখলাম রান্না করছে । আমি বসে সবার সাথে গল্প করছি । হঠাৎ কলিং বেল বেজে উঠলো । তানিয়া চলে গেল দরজা খুলতে । আরে এতো মুকেশ বাবু বাবা আপনি হ্যা চলে আসলাম মিরাজ তোমার পরিবারের সাথে সময় কাটাতে ।মুকেশ বাবু ভালো করেছেন বাবা । তিয়া বাবাকে রুম দেখিয়ে দে তিয়াকে উদ্দেশ্য করে। যান বাবা ফ্রেস হয়ে আসুন । মুকেশ বাবু ফ্রেস হয়ে আসলেন । সবাই ব্রেকফাস্ট করতে বসে গেলাম । ব্রেকফাস্ট সেরে সবাই এক জায়গায় বসলাম । আরাধা আমার কোলে আর চাঁদনিতো আমার একহাত জড়িয়ে বসে আছে । বাবা বল কি হয়েছিল সে দিন মা আমায় জিগ্গাসা করলো আমি বলতে শুরু করলাম তুমি বাড়ী থেকে বের ক
# ...

# %%
# double or multiple  white space convert into single white space
def remove_extra_space(mystring):
    '''
   double or multiple  white space convert into single white space
    '''
    while '  ' in mystring:
        mystring = mystring.replace('  ', ' ')
    mystring = mystring.strip()
    return mystring

# %%
# //here removing the bangla digit  from the text
df['Clean_Text'] = df['Clean_Text'].str.replace('১','')
df['Clean_Text'] = df['Clean_Text'].str.replace('২','')
df['Clean_Text'] = df['Clean_Text'].str.replace('৩','')
df['Clean_Text'] = df['Clean_Text'].str.replace('৪','')
df['Clean_Text'] = df['Clean_Text'].str.replace('৫','')
df['Clean_Text'] = df['Clean_Text'].str.replace('৬','')
df['Clean_Text'] = df['Clean_Text'].str.replace('৭','')
df['Clean_Text'] = df['Clean_Text'].str.replace('৮','')
df['Clean_Text'] = df['Clean_Text'].str.replace('৯','')
df['Clean_Text'] = df['Clean_Text'].str.replace('০','')
df['Clean_Text'] = df['Clean_Text'].str.replace('  ',' ')
# Out:
# <ipython-input-226-71762a51f24e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Clean_Text'] = df['Clean_Text'].str.replace('১','')
# <ipython-input-226-71762a51f24e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Clean_Text'] = df['Clean_Text'].str.replace('২','')
# <ipython-input-226-71762a51f24e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# applying the method remove_Extra_space # double or multiple  white space convert into single white space
df['Clean_Text'] = df.apply(lambda row : remove_extra_space(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-227-a713b491c506>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Clean_Text'] = df.apply(lambda row : remove_extra_space(row['Clean_Text']), axis = 1)

# %%
df.Clean_Text[3]
# Out:
# 'গল্প সিনিয়রগুন্ডিবউ লেখক বাংলা আসলে তানিয়া আমায় ভালোবাসে । ও এমন মূহুর্তে আমার সাথে ছিল যখন আমি নিজেই নিজেকে জানতাম না । আমি ওর কাছে ঋণী । কি বলবো ওকে আমি ও বা এখন কি করবে আমার সাথে নাহ ও আমার জন্য অনেক কিছু করেছে । ও যদি আমায় বিয়ে করতে চায় তবে আমার ওকে মেনে নিতেই হবে । তানিয়ার ব্যাপারে চাঁদনিকে জানানো উচিৎ । এসব ভাবতে ভাবতেই নিচে চলে গেলাম । সবাই একসাথে বসে আছে । আরাধা আমাকে দেখেই বাবাই বলে ছুটে আসলো আমার কাছে । আমি ওকে কোলে নিয়ে সবার কাছে গেলাম । চাঁদনিকে দেখলাম রান্না করছে । আমি বসে সবার সাথে গল্প করছি । হঠাৎ কলিং বেল বেজে উঠলো । তানিয়া চলে গেল দরজা খুলতে । আরে এতো মুকেশ বাবু বাবা আপনি হ্যা চলে আসলাম মিরাজ তোমার পরিবারের সাথে সময় কাটাতে ।মুকেশ বাবু ভালো করেছেন বাবা । তিয়া বাবাকে রুম দেখিয়ে দে তিয়াকে উদ্দেশ্য করে। যান বাবা ফ্রেস হয়ে আসুন । মুকেশ বাবু ফ্রেস হয়ে আসলেন । সবাই ব্রেকফাস্ট করতে বসে গেলাম । ব্রেকফাস্ট সেরে সবাই এক জায়গায় বসলাম । আরাধা আমার কোলে আর চাঁদনিতো আমার একহাত জড়িয়ে বসে আছে । বাবা বল কি হয়েছিল সে দিন মা আমায় জিগ্গাসা করলো আমি বলতে শুরু করলাম তুমি বাড়ী থেকে বের ক
# ...

# %%
# sample(frac=1)--> it makes the data shuffling randomly
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#                                  Title                        Author  \
# 0                       শুধু আমারই💌-12                   🌛🌛চন্দ্রা🌜🌜
# 1      G . R . B :(১১) টা.. টা , গ্রীন                   Red Eclipse
# 2         Mayajal (an evil love story)  Meherun Nesa "কল্পনা বিলাসী"
# 3                  হৃদয়ের অন্তরালে-37                    SOMA GHOSH
# 4                          পর্ব চোদ্দো                 🍁 অনিন্দিতা 🍁
# ...                                ...                           ...
# 25736                            খাঁটি          Nitu Biswas "মিষ্টি"
# 25737      বোঝে না সে বোঝে না-পর্ব-ষোল                    Rumpa Bera
# 25738                         পর্ব ছয়                 🍁 অনিন্দিতা 🍁
# 25739                      লাল ত্রিকোণ            শর্মিষ্ঠা "মিষ্টি"
# 25740            দিগন্তরেখার ভালবাসারা                 সোমাদ্রি সাহা
#
#                                                     Text           Category  \
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                  Title                        Author  \
# 0                       শুধু আমারই💌-12                   🌛🌛চন্দ্রা🌜🌜
# 1      G . R . B :(১১) টা.. টা , গ্রীন                   Red Eclipse
# 2         Mayajal (an evil love story)  Meherun Nesa "কল্পনা বিলাসী"
# 3                  হৃদয়ের অন্তরালে-37                    SOMA GHOSH
# 4                          পর্ব চোদ্দো                 🍁 অনিন্দিতা 🍁
# ...                                ...                           ...
# 25736                            খাঁটি          Nitu Biswas "মিষ্টি"
# 25737      বোঝে না সে বোঝে না-পর্ব-ষোল                    Rumpa Bera
# 25738                         পর্ব ছয়                 🍁 অনিন্দিতা 🍁
# 25739                      লাল ত্রিকোণ            শর্মিষ্ঠা "মিষ্টি"
# 25740            দিগন্তরেখার ভালবাসারা                 সোমাদ্রি সাহা
#
#                                                     Text           Category  \
# ...

# %%
# Look at classification type counts
counts = df.Category.value_counts()
print(len(counts))
print(counts)
# Out:
# 8
# প্রেমকাহিনী          7594
# রহস্যগল্প            5437
# ধারাবাহিক কাহিনী     2574
# স্মৃতিকথা            2207
# হাস্যকৌতুক           2141
# নারী বিষয়ক কাহিনী    1999
# ছোটগল্প              1976
# ভৌতিক গল্প           1813
# Name: Category, dtype: int64

# %%
# Calculate the Length of each Document
df['Length'] = df.Clean_Text.apply(lambda x:len(x.split()))

# %%
df
# Out:
#                                  Title                        Author  \
# 0                       শুধু আমারই💌-12                   🌛🌛চন্দ্রা🌜🌜
# 1      G . R . B :(১১) টা.. টা , গ্রীন                   Red Eclipse
# 2         Mayajal (an evil love story)  Meherun Nesa "কল্পনা বিলাসী"
# 3                  হৃদয়ের অন্তরালে-37                    SOMA GHOSH
# 4                          পর্ব চোদ্দো                 🍁 অনিন্দিতা 🍁
# ...                                ...                           ...
# 25736                            খাঁটি          Nitu Biswas "মিষ্টি"
# 25737      বোঝে না সে বোঝে না-পর্ব-ষোল                    Rumpa Bera
# 25738                         পর্ব ছয়                 🍁 অনিন্দিতা 🍁
# 25739                      লাল ত্রিকোণ            শর্মিষ্ঠা "মিষ্টি"
# 25740            দিগন্তরেখার ভালবাসারা                 সোমাদ্রি সাহা
#
#                                                     Text           Category  \
# ...

# %%
df['Uncleaned_Length'] = df.Text.apply(lambda x:len(x.split()))

# %%
df.head(50)
# Out:
#                                                 Title  \
# 0                                      শুধু আমারই💌-12
# 1                     G . R . B :(১১) টা.. টা , গ্রীন
# 2                        Mayajal (an evil love story)
# 3                                 হৃদয়ের অন্তরালে-37
# 4                                         পর্ব চোদ্দো
# 5                                        রূপকথার গল্প
# 6                                            জুলাই ২৭
# 7                              আমার পৃথিবী তুমি......
# 8                                   জি বি রোডের দালাল
# 9                     তোমায় হৃদমাঝারে রাখিব পর্বঃ-১৪
# 10                     Magical Love [Season 2]Part 23
# 11                      তোমাকেই চাই- //2// পর্ব-২৪ //
# 12                       ফেলে আসা দিনগুলি । আলপনা নাথ
# 13                               কাহিনী#3(ভয়ংকর বিয়ে)
# 14                🥰 তা বলে কী প্রেম দেবো না 🥰 Part 24
# 15                 🥰 তা বলে কী প্রেম দেবো না 🥰 Part 1
# ...

# %%
# Look at classification type counts
counts = df.Category.value_counts()
print(len(counts))
print(counts)
# Out:
# 8
# প্রেমকাহিনী          7594
# রহস্যগল্প            5437
# ধারাবাহিক কাহিনী     2574
# স্মৃতিকথা            2207
# হাস্যকৌতুক           2141
# নারী বিষয়ক কাহিনী    1999
# ছোটগল্প              1976
# ভৌতিক গল্প           1813
# Name: Category, dtype: int64

# %%
prem_kahini = df.loc[(df['Category'] == 'প্রেমকাহিনী')]
rohosso_golpo = df.loc[(df['Category'] == 'রহস্যগল্প')]
darabahik_kahini = df.loc[(df['Category'] == 'ধারাবাহিক কাহিনী')]
smiriti_kotha = df.loc[(df['Category'] == 'স্মৃতিকথা')]
hasso = df.loc[(df['Category'] == 'হাস্যকৌতুক')]
nari = df.loc[(df['Category'] == 'নারী বিষয়ক কাহিনী')]
choto = df.loc[(df['Category'] == 'ছোটগল্প')]
bhoutik = df.loc[(df['Category'] == 'ভৌতিক গল্প')]

# %%
print(prem_kahini.shape)
print(rohosso_golpo.shape)
print(darabahik_kahini.shape)
print(smiriti_kotha.shape)
print(hasso.shape)
print(nari.shape)
print(choto.shape)
print(bhoutik.shape)
# Out:
# (7594, 7)
# (5437, 7)
# (2574, 7)
# (2207, 7)
# (2141, 7)
# (1999, 7)
# (1976, 7)
# (1813, 7)

# %%
from bnlp.corpus import stopwords
from bnlp.corpus.util import remove_stopwords
# Out:
# D:\Anaconda\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
def stop_words_remover(text):
  result = remove_stopwords(text, stopwords)
  return result

# %%
def remove_coma(text):
  if type(text) != str:
    text =' '.join([str(elem) for elem in text])
  return text

# %% [markdown]
# ### StopWords Remove

# %%
prem_kahini['Clean_Text'] = prem_kahini.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-253-5b6dd6faab59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prem_kahini['Clean_Text'] = prem_kahini.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)

# %%
prem_kahini
# Out:
#                                      Title                   Author  \
# 0                           শুধু আমারই💌-12              🌛🌛চন্দ্রা🌜🌜
# 3                      হৃদয়ের অন্তরালে-37               SOMA GHOSH
# 4                              পর্ব চোদ্দো            🍁 অনিন্দিতা 🍁
# 9          তোমায় হৃদমাঝারে রাখিব পর্বঃ-১৪           Aaishiki Ghosh
# 14     🥰 তা বলে কী প্রেম দেবো না 🥰 Part 24  আমি আমার মতো শ্রে য় সী
# ...                                    ...                      ...
# 25732                তোমাকে ফিরে পাওয়া #35  শুভদীপ দাস "মনের আভাস "
# 25733          ভালোবাসার আরেক নাম তুমি #28  শুভদীপ দাস "মনের আভাস "
# 25734          দুই পৃথিবী ( পর্ব ঊনচল্লিশ)          চম্পা চক্রবর্তী
# 25738                             পর্ব ছয়            🍁 অনিন্দিতা 🍁
# 25739                          লাল ত্রিকোণ       শর্মিষ্ঠা "মিষ্টি"
#
#                                                     Text     Category  \
# 0      সমীরণ  স্পট  ডেড  !!!!    এই  একটা  কথাই  যেন ...  প্রেমকাহিনী
# ...

# %%
rohosso_golpo['Clean_Text'] = rohosso_golpo.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-255-11c20378bc5f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rohosso_golpo['Clean_Text'] = rohosso_golpo.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)

# %%
darabahik_kahini['Clean_Text'] = darabahik_kahini.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-256-6c543993bc37>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   darabahik_kahini['Clean_Text'] = darabahik_kahini.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)

# %%
smiriti_kotha['Clean_Text'] = smiriti_kotha.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-257-5658d5ea80ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smiriti_kotha['Clean_Text'] = smiriti_kotha.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)

# %%
hasso['Clean_Text'] = hasso.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-258-845c2727b113>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hasso['Clean_Text'] = hasso.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)

# %%
nari['Clean_Text'] = nari.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-259-730a0bf9aa12>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nari['Clean_Text'] = nari.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)

# %%
choto['Clean_Text'] = choto.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-260-1fae09f9a9ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   choto['Clean_Text'] = choto.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)

# %%
bhoutik['Clean_Text'] = bhoutik.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-261-fac86d93ff40>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bhoutik['Clean_Text'] = bhoutik.apply(lambda row : stop_words_remover(row['Clean_Text']), axis = 1)

# %% [markdown]
# ### Coma Remove

# %%
prem_kahini['Clean_Text'] = prem_kahini.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-262-9de3890532cf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prem_kahini['Clean_Text'] = prem_kahini.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)

# %%
prem_kahini
# Out:
#                                      Title                   Author  \
# 0                           শুধু আমারই💌-12              🌛🌛চন্দ্রা🌜🌜
# 3                      হৃদয়ের অন্তরালে-37               SOMA GHOSH
# 4                              পর্ব চোদ্দো            🍁 অনিন্দিতা 🍁
# 9          তোমায় হৃদমাঝারে রাখিব পর্বঃ-১৪           Aaishiki Ghosh
# 14     🥰 তা বলে কী প্রেম দেবো না 🥰 Part 24  আমি আমার মতো শ্রে য় সী
# ...                                    ...                      ...
# 25732                তোমাকে ফিরে পাওয়া #35  শুভদীপ দাস "মনের আভাস "
# 25733          ভালোবাসার আরেক নাম তুমি #28  শুভদীপ দাস "মনের আভাস "
# 25734          দুই পৃথিবী ( পর্ব ঊনচল্লিশ)          চম্পা চক্রবর্তী
# 25738                             পর্ব ছয়            🍁 অনিন্দিতা 🍁
# 25739                          লাল ত্রিকোণ       শর্মিষ্ঠা "মিষ্টি"
#
#                                                     Text     Category  \
# 0      সমীরণ  স্পট  ডেড  !!!!    এই  একটা  কথাই  যেন ...  প্রেমকাহিনী
# ...

# %%
rohosso_golpo['Clean_Text'] = rohosso_golpo.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-264-81b148481fe4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rohosso_golpo['Clean_Text'] = rohosso_golpo.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)

# %%
darabahik_kahini['Clean_Text'] = darabahik_kahini.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-265-20afccf6378f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   darabahik_kahini['Clean_Text'] = darabahik_kahini.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)

# %%
smiriti_kotha['Clean_Text'] = smiriti_kotha.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-266-052a9b6188f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smiriti_kotha['Clean_Text'] = smiriti_kotha.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)

# %%
hasso['Clean_Text'] = hasso.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-267-c3a95906f280>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hasso['Clean_Text'] = hasso.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)

# %%
nari['Clean_Text'] = nari.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-268-f1eae5503030>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nari['Clean_Text'] = nari.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)

# %%
choto['Clean_Text'] = choto.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-269-81ae0706a104>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   choto['Clean_Text'] = choto.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)

# %%
bhoutik['Clean_Text'] = bhoutik.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)
# Out:
# <ipython-input-270-cb41f62e3784>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bhoutik['Clean_Text'] = bhoutik.apply(lambda row : remove_coma(row['Clean_Text']), axis = 1)

# %%
merged_df = pd.concat([prem_kahini,rohosso_golpo, darabahik_kahini,smiriti_kotha,hasso, nari,choto,bhoutik])

# %%
merged_df
# Out:
#                                      Title                          Author  \
# 0                           শুধু আমারই💌-12                     🌛🌛চন্দ্রা🌜🌜
# 3                      হৃদয়ের অন্তরালে-37                      SOMA GHOSH
# 4                              পর্ব চোদ্দো                   🍁 অনিন্দিতা 🍁
# 9          তোমায় হৃদমাঝারে রাখিব পর্বঃ-১৪                  Aaishiki Ghosh
# 14     🥰 তা বলে কী প্রেম দেবো না 🥰 Part 24         আমি আমার মতো শ্রে য় সী
# ...                                    ...                             ...
# 25662                               চিত্রা                     ছেঁড়া খাতা
# 25663                     মাঝরাতের কলিংবেল  Shreyanki Karar "শ্রেয়াঙ্কি🍁"
# 25667                     ভুলুর মানুষ চেনা                  শঙ্খ চক্রবর্তী
# 25677        Dangerous প্রেমিকা (পর্ব::১২)               নীল পরী "নীল পরী"
# 25685                         অশরীরী প্রেম  Shreyanki Karar "শ্রেয়াঙ্কি🍁"
#
# ...

# %%
def lower_string(mystring):
    '''
    mystring is the total text of a columns where multiple white space are beeing removed and lower the all charecters
    '''
    while '  ' in mystring:
        mystring = mystring.replace('  ', ' ')
    mystring = mystring.strip()
    return mystring

# %%
merged_df['Clean_Text'] = merged_df.apply(lambda row : lower_string(row['Clean_Text']), axis = 1)

# %%
merged_df = merged_df.sample(frac=1).reset_index(drop=True)

# %%
merged_df
# Out:
#                                                Title  \
# 0                                  বন্দিনী (পর্ব ৫৯)
# 1                                     কষ্টের ঠিকানা।
# 2                             পিএর প্রেমে বস পর্ব ৩৩
# 3                                            পর্ব-০৫
# 4                                       #শুভতিথি (৩)
# ...                                              ...
# 25736                         রাজনন্দিনী (পর্ব:::২১)
# 25737  প্রেম, দাম্পত্য ও ক্রিকেট রহস্য: নন্দিনীর কথা
# 25738                                             মা
# 25739                                      শাপমুক্তি
# 25740                                      সীমাবদ্ধ।
#
#                                                  Author  \
# 0                                          Ratna Halder
# 1                                হৃদয় তামিম "বাপ্পারাজ"
# 2                                             😎Nandita😎
# 3                                          Niloy Shoron
# ...

# %%
merged_df.to_csv("dataset.csv",encoding='utf-8')

# %%
f = pd.read_csv("dataset.csv")

# %%
f
# Out:
#        Unnamed: 0                                          Title  \
# 0               0                              বন্দিনী (পর্ব ৫৯)
# 1               1                                 কষ্টের ঠিকানা।
# 2               2                         পিএর প্রেমে বস পর্ব ৩৩
# 3               3                                        পর্ব-০৫
# 4               4                                   #শুভতিথি (৩)
# ...           ...                                            ...
# 25736       25736                         রাজনন্দিনী (পর্ব:::২১)
# 25737       25737  প্রেম, দাম্পত্য ও ক্রিকেট রহস্য: নন্দিনীর কথা
# 25738       25738                                             মা
# 25739       25739                                      শাপমুক্তি
# 25740       25740                                      সীমাবদ্ধ।
#
#                                                  Author  \
# 0                                          Ratna Halder
# 1                                হৃদয় তামিম "বাপ্পারাজ"
# ...
